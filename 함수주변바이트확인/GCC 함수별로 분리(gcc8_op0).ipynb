# %% [markdown]
# ## 1. 데이터 로드

# %%
# (1) 데이터로드
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings(action='ignore')

# 여러개 쳐도 나오게
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# 파일읽기
gcc8_0_32 = pd.read_csv("../binutils_gcc3~9_op0~4_csv/"+'gcc8'+"_0_32.csv", index_col=0)

# 형태 출력
print(gcc8_0_32.shape)

# reset_index (hex processing 하면서 값이 빠졌으니까 + n_gram 에서 index를 다루기 때문에)
gcc8_0_32.reset_index(inplace=True, drop=True)

print('reset_index 완료')
print('input data shape')
gcc8_0_32.head()
# Out:
# (2337112, 2)
# reset_index 완료
# input data shape
#   hex  bin
# 0  55    1
# 1  89    0
# 2  e5    0
# 3  56    0
# 4  53    0

# %% [markdown]
# ## 2. Data 확인

# %%
# DATA 모양 확인
gcc8_0_32.values
print(gcc8_0_32.shape)

# 함수의 갯수
gcc8_0_32['bin'].value_counts()

# 함수 평균길이
gcc8_0_32['bin'].value_counts()[0]/gcc8_0_32['bin'].value_counts()[1]
# Out:
# array([['55', 1],
#        ['89', 0],
#        ['e5', 0],
#        ...,
#        ['1c', 0],
#        ['24', 0],
#        ['c3', 0]], dtype=object)
# (2337112, 2)
# 0    2324953
# 1      12159
# Name: bin, dtype: int64
# 191.21251747676618

# %% [markdown]
# ## 3. 함수의 갯수, 바이트 갯수의 빈공간 np.array 생성

# %%
x = np.full((gcc8_0_32['bin'].value_counts()[1],30000), None, dtype='object')
x.shape
x.dtype
# Out:
# (12159, 30000)
# dtype('O')

# %% [markdown]
# ## 4. 함수 빈공간에 함수별로 한줄씩 값 대입

# %%
data = gcc8_0_32.values

row = -1
col = 0
col_list=[]

# data => [55,1], [89,1], [e5,1] ....
for i in data:
    # i[0] = 55, 89, e5... /  i[1] = 1, 0, 0, ....
    if i[1]==1:
        col_list.append(col) # col_list의 각 함수 길이들 넣는다.
        
        row+=1
        col=0
        x[row][col] = i[0]
#        print(row,col, end='/') # 오류났을 때 풀어보면 몇번째 행에서 값을 초과하는지 알 수 있음.
    else:
        x[row][col+1] = i[0]
        #if row >=1385:
        #    print(row,col, end=' ')
        col+=1
    
print('대입 완료')
# Out:
# 대입 완료

# %%
max(col_list)
# Out:
# 21826

# %% [markdown]
# ## 5. 최적의 x 찾기

# %%
# 예시
x[:, :5]
print(len(col_list),'\n')

# 최소 3gram ~ 7gram 까지확인
for j in range(2, 7):
    tuple_ls = []
    for k in x[:, :j]:
        tuple_ls.append(tuple(k))

    set_ls = set(tuple_ls)
    print(j, 'gram일 때 ', len(set_ls))
# Out:
# array([['55', '89', 'e5', '56', '53'],
#        ['8b', '1c', '24', 'c3', '55'],
#        ['55', '89', 'e5', 'e8', 'fc'],
#        ...,
#        ['8b', '1c', '24', 'c3', None],
#        ['55', '89', 'e5', '53', '83'],
#        ['8b', '1c', '24', 'c3', None]], dtype=object)
# 12159
#
# 2 gram일 때  101
# 3 gram일 때  768
# 4 gram일 때  4518
# 5 gram일 때  4681
# 6 gram일 때  5128

# %%
# 임의 테스트
tls = []
for t in x[:, :4]:
    tls.append(tuple(t))
    
stls = set(tls)
stls
# Out:
# {('8d', '80', '10', '66'),
#  ('8d', '80', 'eb', '77'),
#  ('8d', '80', 'e0', '77'),
#  ('8d', '80', 'd9', '46'),
#  ('8b', '85', '34', 'fe'),
#  ('b8', '83', '01', '00'),
#  ('8b', '93', '8c', '00'),
#  ('8d', '80', '76', '3c'),
#  ('8d', '80', '6c', '30'),
#  ('8d', '83', '8c', '14'),
#  ('8b', '85', '64', 'ff'),
#  ('8d', '80', '7b', '14'),
#  ('c7', '83', '00', '00'),
#  ('8d', '80', 'c2', '4a'),
#  ('8d', '80', 'af', '23'),
#  ('8d', '80', '1a', '8b'),
#  ('8d', '83', '30', '15'),
#  ('8d', '80', 'f1', 'e4'),
#  ('8d', '80', '05', '3b'),
#  ('8d', '80', '4e', '25'),
#  ('8d', '80', '93', '30'),
#  ('8d', '80', '9a', '9c'),
#  ('8d', '80', '26', '2f'),
#  ('8d', '80', 'f1', 'a0'),
#  ('8d', '80', 'ba', 'fe'),
#  ('8d', '80', 'e7', '91'),
#  ('8d', '80', '08', 'c7'),
#  ('8d', '80', '1a', '49'),
#  ('8d', '80', '7b', '35'),
#  ('8d', '80', '93', 'f8'),
#  ('8d', '80', 'bb', '9f'),
#  ('b8', '0d', '01', '00'),
#  ('8d', '80', 'c0', '42'),
#  ('8d', '80', 'c1', '49'),
# ...
